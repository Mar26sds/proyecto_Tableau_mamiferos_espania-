# %%
import pandas as pd

# %%
data= pd.read_json('/Users/mar/Desktop/w5 /jsontabla.json')

# %%
data.replace('', 'unknown',inplace=True)

# %%
data.to_csv('/Users/mar/Desktop/w5 /w5.csv')

# %%
data.to_excel('/Users/mar/Desktop/w5 /w51.xlsx')

# %%
data
# Out:
#         nombre_científico          nombre_común         autoridad  \
# 0                ama dama                 Gamo            unknown
# 1       Ammotragus lervia                Arrui            unknown
# 2    Apodemus flavicollis        Ratón leonado   (Melchior, 1834)
# 3     Apodemus sylvaticus       Ratón de campo   (Linnaeus, 1758)
# 4          apra pyrenaica         Cabra montés            unknown
# ..                    ...                   ...               ...
# 125    Tursiops truncatus   Delfín mular común    (Montagu, 1821)
# 126          Ursus arctos            Oso pardo     Linnaeus, 1758
# 127   Vespertilio murinus   Murciélago bicolor            unknown
# 128         Vulpes vulpes                Zorro   (Linnaeus, 1758)
# 129   Ziphius cavirostris  Ballenato de Cuvier    G. Cuvier, 1823
#
#     categoría_de_amenaza   origen
# 0                unknown  unknown
# 1                unknown  unknown
# 2                     LC   Nativa
# ...
